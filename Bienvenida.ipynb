# %% [markdown]
# ![tutorial banner](images/tutorial_banner.PNG)
#
# # Bievenid@s!

# %% [markdown]
# ## Como usar este tutorial
#
# Este tutorial utiliza cuadernos (notebooks) de [Jupyter](https://jupyter.org). Jupyter es una herramienta interactiva basada en tu buscador de internet, que combina texto, imagenes, ecuaciones, y código que pueden ser compartidos con otros.

# %% [markdown]
# ## Cómo navegar y abrir los cuadernos
#
# En la barra a tu izquierda puedes navegar por los distintos cuadernos o capítulos de este tutorial. Si no has usado Jupyter o python antes, te recomendamos empieces con el cuaderno `0 Introduccion a Jupyter y Python`
#
# Despues de hacer click en el cuaderno que quieres usar, haz click en el Icono del Cohete en la parte superior derecha, y selecciona Collab
# ![image.png](attachment:fc39ae6a-5ac3-4541-83a5-9129f4a845d2.png)
#
# Esto abrira el cuaderno en Google Collab, donde podras correr el código sin instalar nada en tu computador, con exception de copiar los archivos de SMARTS como se especifica a continuación. Para correr en Google Collab, necesitaras una cuenta de Google. Si no tiense esto, puedes al menos leer el texto ya incluido, o hacer una instalación manual de todo el software como se especifica [aquí](https://github.com/NREL/pySMARTS)
#
# ## Agregar SMARTS
#
# Una vez que tengas abierto un cuaderno en Google Collab, baja SMARTS y unzip el folder. Después copia los archivos adentro del folder `SMARTS_295_PC` que inician con `smarts`, arrastrandolos al folder de tu Google Collab (si no lo ves, lo puedes abrir presionando en el ícono del folder en el lado superior derecho). Tendrás que copiar estos archivos en cada nuevo cuaderno que abras.
#
# ![image.png](attachment:afebe7b7-795c-4d14-bd62-0e95d0ac3ae5.png)
